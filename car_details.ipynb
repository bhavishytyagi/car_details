# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Car Details Data.csv')
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
df1=df['name'].unique()
df1
# Out:
# array(['Maruti 800 AC', 'Maruti Wagon R LXI Minor',
#        'Hyundai Verna 1.6 SX', ..., 'Mahindra Verito 1.5 D6 BSIII',
#        'Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV',
#        'Hyundai i20 Magna 1.4 CRDi'], dtype=object)

# %%
df['year'].unique()
# Out:
# array([2007, 2012, 2017, 2014, 2016, 2015, 2018, 2019, 2013, 2011, 2010,
#        2009, 2006, 1996, 2005, 2008, 2004, 1998, 2003, 2002, 2020, 2000,
#        1999, 2001, 1995, 1997, 1992])

# %%
df['fuel'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
df['transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Fourth & Above Owner',
#        'Third Owner', 'Test Drive Car'], dtype=object)

# %% [markdown]
# Counts of cars in possession WRT its make year

# %%
ax=sns.countplot(x='year',data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40 ,ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Top 5 in Petrol WRT selling price

# %%
pt=df[df['fuel']== 'Petrol']
pt.sort_values(by=['selling_price'],ascending=False)
# Out:
#                                             name  year  selling_price  \
# 3872    Audi RS7 2015-2019 Sportback Performance  2016        8900000
# 2580  Mercedes-Benz E-Class Exclusive E 200 BSIV  2018        4500000
# 101   Mercedes-Benz E-Class Exclusive E 200 BSIV  2018        4500000
# 988               Land Rover Discovery S 2.0 SD4  2018        4000000
# 1065                  Audi A4 30 TFSI Technology  2018        3100000
# ...                                          ...   ...            ...
# 1832                             Tata Nano LX SE  2012          35000
# 3206                            OpelCorsa 1.4 GL  2002          35000
# 2444                               Maruti 800 EX  2004          30000
# 2495                           Ford Ikon 1.4 ZXi  2000          22000
# 2662                       Ford Ikon 1.6 ZXI NXt  2005          20000
#
#       km_driven    fuel seller_type transmission         owner
# 3872      13000  Petrol      Dealer    Automatic   First Owner
# ...

# %% [markdown]
# Top 5 in Diesel WRT max selling price

# %%
ds=df[df['fuel']=='Diesel']
ds.sort_values(by=['selling_price'],ascending=False)
# Out:
#                                                    name  year  selling_price  \
# 89    Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017        8150000
# 3969            Mercedes-Benz GLS 2016-2020 350d 4MATIC  2016        5500000
# 919                             BMW X5 xDrive 30d xLine  2019        4950000
# 612                             BMW X5 xDrive 30d xLine  2019        4950000
# 593                             BMW X5 xDrive 30d xLine  2019        4950000
# ...                                                 ...   ...            ...
# 729                                      Tata Indigo LS  2007          55000
# 1433                                    Tata Indica DLS  2006          50000
# 334                                     Tata Indica DLX  2003          50000
# 2878                        Ambassador Classic 2000 Dsz  2002          50000
# 1782                                    Tata Indica DLE  2006          45000
#
# ...

# %% [markdown]
# Top 5 in CNG WRT max selling price

# %%
cng=df[df['fuel']=='CNG']
cng.sort_values(by=['selling_price'],ascending=False)
# Out:
#                                         name  year  selling_price  km_driven  \
# 4076                   Maruti Ertiga VXI CNG  2014         595000      56600
# 3464                   Maruti Ertiga VXI CNG  2018         587000      80000
# 712                    Maruti Ertiga VXI CNG  2013         525000      56228
# 2785           Hyundai Santro Magna CNG BSIV  2019         520000      10000
# 3112        Maruti Eeco CNG 5 Seater AC BSIV  2020         495000       7000
# 3778        Maruti Eeco CNG 5 Seater AC BSIV  2019         470000       4000
# 3048        Maruti Eeco CNG 5 Seater AC BSIV  2019         470000      10000
# 4063  Maruti Eeco 5 STR With AC Plus HTR CNG  2017         440000      14100
# 4140  Maruti Eeco 5 STR With AC Plus HTR CNG  2018         409999      45000
# 22                  Maruti Celerio Green VXI  2017         365000      78000
# 4001                Maruti Celerio Green VXI  2017         365000      78000
# ...

# %% [markdown]
# Top 5 in LPG WRT max selling price

# %%
lpg=df[df['fuel']=='LPG']
lpg.sort_values(by=['selling_price'],ascending=False)
# Out:
#                                            name  year  selling_price  \
# 1435                      Hyundai i10 Magna LPG  2014         290000
# 1998                      Hyundai i10 Magna LPG  2013         275000
# 495           Hyundai Santro Xing GLS Audio LPG  2012         250000
# 657                       Hyundai i10 Magna LPG  2013         250000
# 3752                 Hyundai EON LPG Magna Plus  2015         240000
# 2380                     Maruti Wagon R Duo Lxi  2010         240000
# 703             Hyundai Santro Xing GL Plus LPG  2011         229999
# 1355                Maruti Wagon R LXI LPG BSIV  2012         220000
# 157                      Maruti Wagon R DUO LPG  2014         210000
# 3341                      Chevrolet Beat LT LPG  2011         200000
# 483                  Hyundai EON LPG Magna Plus  2012         180000
# 1670               Maruti Wagon R LXI DUO BS IV  2012         180000
# 3394                 Hyundai EON LPG Magna Plus  2012         170000
# ...

# %% [markdown]
# Top 5 in Electric WRT max selling price

# %%
elc=df[df['fuel']=='Electric']
elc.sort_values(by=['selling_price'],ascending=False)
# Out:
#                      name  year  selling_price  km_driven      fuel  \
# 4145  Toyota Camry Hybrid  2006         310000      62000  Electric
#
#      seller_type transmission         owner
# 4145      Dealer    Automatic  Second Owner

# %% [markdown]
# Top 5 cars with min selling price and min kms driven

# %%
minsp=df.nsmallest(50,'selling_price')
minsp.nsmallest(5,'km_driven')
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 1468     Tata Nano Cx BSIII  2014          45000       7000  Petrol
# 4158     Tata Nano Cx BSIII  2014          45000       7000  Petrol
# 877           Tata Nano Std  2011          40000      19000  Petrol
# 2662  Ford Ikon 1.6 ZXI NXt  2005          20000      25000  Petrol
# 340           Tata Nano STD  2013          55000      25000  Petrol
#
#      seller_type transmission                 owner
# 1468  Individual       Manual          Second Owner
# 4158  Individual       Manual          Second Owner
# 877   Individual       Manual           First Owner
# 2662  Individual       Manual          Second Owner
# 340   Individual       Manual  Fourth & Above Owner

# %% [markdown]
# suggest a car consider to be buying (Manual)
# I consider here minimum km_driven , recently year of manufracturer and First owner.

# %%
man=df[df['transmission']=='Manual']
man1=man[df['owner']=='First Owner']
man1[df['km_driven']<5000].sort_values(by=['year'],ascending=False)
# Out:
# <ipython-input-16-54a7bd623a2d>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   man1=man[df['owner']=='First Owner']
# <ipython-input-16-54a7bd623a2d>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   man1[df['km_driven']<5000].sort_values(by=['year'],ascending=False)
#                                          name  year  selling_price  km_driven  \
# 2129                  Honda BR-V i-VTEC VX MT  2020        1250000       1100
# 1195                       Maruti Baleno Zeta  2020         700000       1100
# 4105                          Tata Harrier XE  2020         426000       1000
# 3431          Hyundai Venue SX Opt Turbo BSIV  2020        1050000       1100
# 3268                         Maruti Swift VXI  2020         619000       1500
# 3050                      Maruti Alto 800 LXI  2020         310000       1700
# 2154              Ford Ecosport Sports Petrol  2020        1100000       1000
# ...

# %%
df['brand']= df['name'].str.split().str[0]
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner    brand
# ...
